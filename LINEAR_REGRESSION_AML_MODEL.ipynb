# %%
#LINEAR REGRESSION

# %%
# IMPORT LIBRARIES

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
#LOAD DATASET

data = pd.read_excel('country.xlsx')
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# %%
#PRINT FIRST 5 ROW

data.head()
# Out:
#    Id Code            Name     Description  RiskRating  FATFRISKRating  \
# 0   1   AF     Afghanistan     Afghanistan        6.84               0
# 1   2   AX   Aland Islands   Aland Islands        6.10               0
# 2   3   AL         Albania         Albania       13.00               1
# 3   4   DZ         Algeria         Algeria        6.03               0
# 4   5   AS  American Samoa  American Samoa        6.10               0
#
#   isocode3digit Riskscore  UNCODE  Is_active  ...          created_on  \
# 0           AFG        \N       4          1  ... 2023-02-09 16:54:57
# 1           ALA        \N     248          1  ... 2023-02-09 16:54:57
# 2           ALB        \N       8          1  ... 2023-02-09 16:54:57
# 3           DZA        \N      12          1  ... 2023-02-09 16:54:57
# 4           ASM        \N      16          1  ... 2023-02-09 16:54:57
#
#   updated_by          updated_on Mandatory_document  Optional_document  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0)

# %%
import pickle
from sklearn.preprocessing import LabelEncoder

# Assuming 'payment' is a categorical column in your DataFrame
columns = ['Code', 'Name', 'Description', 'isocode3digit', 'Riskscore', 'Optional_document', 'rating_source', 'risk_assessment']

# Initialize LabelEncoders
label_encoders = {}

# Fit and transform the data
for col in columns:
    label_encoder = LabelEncoder()
    data[col] = data[col].astype(str)  # Convert all values to strings
    type_encoded = label_encoder.fit_transform(data[col])
    data[col+'_encoded'] = type_encoded
    label_encoders[col] = label_encoder

# Save the encoders
for col, encoder in label_encoders.items():
    with open(col+'_encoder.pkl', 'wb') as f:
        pickle.dump(encoder, f)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 from sklearn.linear_model import LinearRegression
#       2 regressor = LinearRegression()
# ----> 3 regressor.fit(X_train, y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
#     661     sample_weight=sample_weight,
#     662 )
#
# ...

# %%
y_pred = regressor.predict(X_test)
